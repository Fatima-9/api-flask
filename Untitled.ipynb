# %% [markdown]
# # myfirstnote
# 2024

# %%
etudiant = {
     "nom": "fatima",
     "age": 24,
     "ville": "Paris"
 }


print(etudiant["ville"])
# Out:
# Paris

# %%
import pandas

# %%
import pandas

# %%
import pandas as pd

# %%
je charge ma memoire
# Out:
#   Cell In[5], line 1
#     je charge ma memoire
#        ^
# SyntaxError: invalid syntax

# %%
data=pd.read_csv(C:\Users\fatim\Downloads\dataset.csv)

# %%
data=pd.read_csv("C:\Users\fatim\Downloads\dataset.csv")

# %%
data = pd.read_csv(C:\Users\fatim\Downloads\dataset.csv\)

# %%
data=pd.read_csv(C:/Users/fatim/Downloads/dataset.csv)

# %%
data=pd.read_csv(r"C:/Users/fatim/Downloads/dataset.csv")

# %%
data_viz=data["FacilityType"].value_counts()

# %%
data["FacilityType"]

# %%
import matplotlib.pyplot as plt

# %%
data_viz.plot(kind="bar")
plt.title('MON DIAGRAMME')

plt.show()

# %%
plt.show()

# %%
plt.show()

# %% [markdown]
# plt.figure(figsize=(10,20))
# plt.title("Myfig")
# plt.pie()
# plt.show()

# %%
plt.figure(figsize=(10,10))
plt.title("Myfig")
plt.pie(data_viz, labels=data_viz.index)
plt.show()

# %%
lat_list=data["Latitude"]
long_list=data["Longitude"]
plt.scatter(long_list,lat_list)

# %%
for index,row in data.iterrows()
print(row)

# %%
for index, row in data.iterrows():
    print(index)  
    print(row["town"])

# %%
for index, row in data.iterrows():
    print(index)  
    print(row)

# %%
for index, row in data.iterrows():
    print(index)  
    print(row)

# %%
for index, row in data.iterrows():
    
    print(row["Town"],row["State"])

# %%
import folium

# %%
carte = folium.Map(location=[data["Latitude"].mean(), data["Longitude"].mean()], zoom_start=4)
folium.Marker([2, 3]).add_to(carte)
c = 0
for index, row in data.iterrows():
    if c == 10:
        break
    else:
        print(row) 
        c += 1
carte
# Out:
# FacilityID                                             1
# URL                  https://toiletmap.gov.au/facility/1
# Name                                 Sandy Beach Reserve
# FacilityType                             Park or reserve
# Address1                           Lost 15525, West Road
# Town                                          Bassendean
# State                                                 WA
# AddressNote                                          NaN
# Latitude                                      -31.921836
# Longitude                                     115.950206
# Parking                                            False
# ParkingAccessible                                  False
# ParkingNote                                          NaN
# KeyRequired                                        False
# MLAK24                                             False
# MLAKAfterHours                                     False
# ...

# %%
data=pd.read_csv(r"C:/Users/fatim/Downloads/dataset.csv")

# %%
data
# Out:
#        FacilityID                                      URL  \
# 0               1      https://toiletmap.gov.au/facility/1
# 1               2      https://toiletmap.gov.au/facility/2
# 2               3      https://toiletmap.gov.au/facility/3
# 3               4      https://toiletmap.gov.au/facility/4
# 4               5      https://toiletmap.gov.au/facility/5
# ...           ...                                      ...
# 23658       62973  https://toiletmap.gov.au/facility/62973
# 23659       62974  https://toiletmap.gov.au/facility/62974
# 23660       62975  https://toiletmap.gov.au/facility/62975
# 23661       62976  https://toiletmap.gov.au/facility/62976
# 23662       62977  https://toiletmap.gov.au/facility/62977
#
#                                     Name     FacilityType  \
# 0                    Sandy Beach Reserve  Park or reserve
# 1                          Point Reserve  Park or reserve
# 2                   Success Hill Reserve  Park or reserve
# ...
